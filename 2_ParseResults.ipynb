# %% [markdown]
# # Web scraping
#
# In this notebook, we will parse the raw data we saved in the last notebook. The output will be a dictionary (saved as a `.json` file) that contains info about song structure and chord progression.

# %%
import requests
from bs4 import BeautifulSoup
import re
from itertools import chain
import json
from collections import Counter
import os
import random
import music_functions as mf

# %%
input_dir = '/Volumes/SECONDDRIVE/prog/ug/raw_data/'
output_dir = '/Volumes/SECONDDRIVE/prog/ug/chord_dicts/'

# %%
decade_dirs = [f.path for f in os.scandir(input_dir) if f.is_dir() and f.path.split("/")[-1].isnumeric()]

# %%
# iterate over each decade
for decade_dir in decade_dirs:
    
    decade = decade_dir.split("/")[-1]
    if not os.path.exists(output_dir + decade):
        os.mkdir(output_dir + decade)
    
    # iterate over each genre
    genre_dirs = [f.path for f in os.scandir(decade_dir) if f.is_dir()]
    
    for genre_dir in genre_dirs:
        
        genre = genre_dir.split("/")[-1]
        if not os.path.exists(output_dir + decade + "/" + genre):
            os.mkdir(output_dir + decade + "/" + genre)
        
        filelist = [input_dir+ decade + "/" + genre + "/" + x for x in os.listdir(input_dir+ decade + "/" + genre + "/")]
        
        for fname in filelist:    

            # check to see if we've already parsed this data before
            outname = output_dir + decade + "/" + genre + "/" + fname.split(".")[0].split("/")[-1] + ".json"
            if os.path.isfile(outname):
                continue

#             print(fname)

            with open(fname, 'r') as file:
                data = file.read().replace('\n', '')

            # convert to beautiful soup object
            soup = BeautifulSoup(data, "html.parser")

            # _3naMH is the class for the "header" data - key, tuning, capo placement
            results = soup.find_all("div", class_="_3naMH")    

            # Identify the key signature and capo
            key_search = [x.get_text().split()[1] for x in results if "Key" in x.get_text()]

            key_signature = 0
            if (len(key_search) > 0):
                key_signature = key_search[0]

            # Identify the guitar tuning (which can impact effect of the capo)
            tuning_search = [ ' '.join(x.get_text().split()[1:]) for x in results if "Tuning" in x.get_text()]    
            tuning_offset = 0

            # there shouldn't be a scenario where tuning search has more than one element
            # either there's 1 (the tuning) or 0 (no tuning specified - assume standard)
            if (len(tuning_search) == 1):
                tuning = tuning_search[0]

                # ignore standard tuning EADGBE and drop D DADGBE because the offset will still be zero
                if tuning == 'E A D G B E' or tuning == 'D A D G B E':
                    tuning_offset = 0
                # half-step down tuning
                elif tuning == 'Eb Ab Db Gb Bb Eb' or tuning == 'D# G# C# F# A# D#':
                    tuning_offset = 1
                elif tuning == 'C G C F A D' or tuning == 'D G C F A D': # d or drop c tuning
                    tuning_offset = 2
                else: # other tunings not currently supported... could return later
                    print("This was a weird tuning")
                    print(tuning)
                    continue
            
            capo_search = [x.get_text().split()[1] for x in results if "Capo" in x.get_text()]
            capo = 0
            if (len(capo_search) > 0):
                # regex is used to remove any letters (so changing "3rd" to just "3")
                x = re.sub("[^0-9]", "", capo_search[0])
                if len(x) > 0:
                    capo = int(x)


            # a capo transposes up, and the tuning generally transposes down
            transpose_offset = capo - tuning_offset

            # identify the locations of different sections
            try:
                song_spans = soup.find_all("pre", class_="_3F2CP _3hukP")[0].find_all("span")
                
                    # identify where the section headers are
                section_header_match = [bool(re.match("<span class=\"_3rlxz\">\[.*\]</span>", str(song_spans[x]))) for x in range(len(song_spans))]
                section_header_idx = [i for i, val in enumerate(section_header_match) if val]
                section_headers = [song_spans[x].get_text() for x in section_header_idx]
                section_header_idx.append(len(song_spans))

                # get chord progression for each section
                chord_progression = {}

                for init_index in range(len(section_header_idx)-1):
                    section = song_spans[section_header_idx[init_index]: section_header_idx[init_index+1]]
                    section_chords = [x.get_text().strip().split() for x in section if str(x).startswith('<span class="_3rlxz">') and '_3PpPJ OrSDI' in str(x)]

                    # removing the equivalencies that some people insert re: capo 
                    section_chords = [x for x in section_chords if '=' not in x]

                    # un-nest list
                    section_chords = [mf.clean_chord(x) for x in list(chain.from_iterable(section_chords))]

                    # remove any special characters (this might remove some info but that's ok)
                    special_characters = ['*', '~']
                    section_chords = [''.join([e for e in x if e not in special_characters]) for x in section_chords]

                    # remove anything else that doesn't match
                    section_chords = [x for x in section_chords if re.match(r"^[ABCDEFG][#b]*[ABCDEFG#bm]*$", x)]

                    chord_progression[init_index] = { 'type' : section_headers[init_index], 'chords' : section_chords}

                # if the chord_progression dictionary is empty, then skip this step
                # this might happen because the song doesn't have labels for different parts of the song (intro, verse, chorus, etc.)
                if not chord_progression:
                    print("Chord progression dictionary is empty")
                    continue

                #TODO so in all cases it's not technically the most occurring (ex: fluorescent adolescent)
                # this could be a good enough approximation tho i guess lol
                if key_signature == 0:
                    key_signature = mf.infer_tonic(mf.get_all_chords(chord_progression))
                else:
                    key_signature = mf.apply_capo(key_signature, transpose_offset)

                # convert to numerics for easier comparison
                for section in chord_progression:
                    chords = chord_progression[section]['chords']
                    chord_progression[section]['chords_numeric'] = [mf.get_relation(key_signature, x) for x in chords]


                with open(outname, 'w') as outfile:
                    json.dump(chord_progression, outfile)
            except:
                continue
# Out:
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/pink-floyd_wish-you-were-here.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/fleetwood-mac_landslide.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/neil-diamond_sweet-caroline.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/pink-floyd_comfortably-numb.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/lynyrd-skynyrd_free-bird.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/the-beatles_dont-let-me-down.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/supertramp_give-a-little-bit.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/rod-stewart_maggie-may.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/the-beatles_get-back.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/elton-john_candle-in-the-wind.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/neil-young_my-my-hey-hey-out-of-the-blue.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/creedence-clearwater-revival_i-heard-it-through-the-grapevine.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/neil-young_the-needle-and-the-damage-done.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/10cc_im-not-in-love.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/blondie_heart-of-glass.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/fleetwood-mac_songbird.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/elton-john_daniel.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/peter-gabriel_solsbury-hill.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/santana_black-magic-woman.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/crosby-stills-nash-young_teach-your-children.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/paul-simon_me-and-julio-down-by-the-schoolyard.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/crosby-stills-nash-young_our-house.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/rupert-holmes_escape-the-pina-colada-song.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/bruce-springsteen_im-on-fire.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/cyndi-lauper_time-after-time.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/carpenters_close-to-you.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/scorpions_still-loving-you.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/bob-seger-the-silver-bullet-band_against-the-wind.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/rick-astley_never-gonna-give-you-up.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/roxy-music_more-than-this.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/michael-jackson_bad.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/barry-manilow_somewhere-down-the-road.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/the-b-52s_love-shack.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1990/4/nirvana_heart-shaped-box.txt
# This was a weird tuning
# Db Ab Db Gb Bb Eb
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1990/4/tom-petty_wildflowers.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1990/4/gary-moore_still-got-the-blues.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1990/4/tracy-chapman_give-me-one-reason.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1990/4/santana_smooth.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1990/4/neutral-milk-hotel_two-headed-boy.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1990/4/kenny-loggins_rainbow-connection.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1990/4/jeff-buckley_lover-you-shouldve-come-over.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1990/4/radiohead_street-spirit-fade-out.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1990/4/david-gray_sail-away.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1990/4/david-gray_babylon.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1990/14/kenny-loggins_rainbow-connection.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1990/14/michael-w-smith_agnus-dei.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1990/14/celine-dion_its-all-coming-back-to-me-now.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1990/14/celine-dion_the-power-of-love.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2000/4/tenacious-d_fuck-her-gently.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2000/4/sufjan-stevens_casimir-pulaski-day.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2000/4/gorillaz_feel-good-inc.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2000/4/jal_aadat.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2000/4/oasis_sad-song.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2000/4/my-chemical-romance_cancer.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/hillsong-united_so-will-i-100-billion-x.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/big-thief_masterpiece.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/x-ambassadors_unsteady.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/harry-styles_kiwi.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/panic-at-the-disco_house-of-memories.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/linkin-park_castle-of-glass.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/mitski_your-best-american-girl.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/mitski_class-of-2013.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/pigeon-pit_nights-like-these.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/cavetown_boys-will-be-bugs.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/paramore_aint-it-fun.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/linkin-park_the-messenger.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/rainbow-kitten-surprise_first-class.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/the-script_for-the-first-time.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/noel-gallaghers-high-flying-birds_if-i-had-a-gun.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/bring-me-the-horizon_drown.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/lucy-dacus_night-shift.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/phum-viphurit_lover-boy.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/demi-lovato_sober.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/greta-van-fleet_youre-the-one.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/boygenius_me-and-my-dog.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/girl-in-red_bad-idea.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/kodaline_all-i-want.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/imagine-dragons_believer.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/one-direction_drag-me-down.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/ricky-montgomery_my-heart-is-buried-in-venice.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/neck-deep_december.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/los-campesinos_romance-is-boring.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/james-blunt_bonfire-heart.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/imagine-dragons_warriors.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/cavetown_fool.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/beach-bunny_prom-queen.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/harry-styles_two-ghosts.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/cavetown_lemon-boy.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/the-script_hall-of-fame.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/kygo_it-aint-me.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/juan-karlos_buwan.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/x-ambassadors_renegades.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/bethel-music_ever-be.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/nothing-but-thieves_lover-please-stay.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/zac-brown-band_knee-deep.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/andreas-bourani_auf-uns.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/cigarettes-after-sex_k.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/arctic-monkeys_do-i-wanna-know.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/clairo_pretty-girl.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/girl-in-red_girls.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/shinedown_simple-man.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/family-of-the-year_hero.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/twenty-one-pilots_the-judge.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/arctic-monkeys_arabella.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/the-1975_robbers.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/harry-styles_ever-since-new-york.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/taylor-swift_mean.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/taylor-swift_never-grow-up.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/kodaline_brother.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/peach-pit_tommys-party.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/james-bay_us.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/michael-w-smith_waymaker.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/two-door-cinema-club_what-you-know.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/foo-fighters_walk.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/grouplove_tongue-tied.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/peach-pit_alrighty-aphrodite.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/natalia-lafourcade_lo-que-construimos.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/cavetown_meteor-shower.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/harry-styles_she.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/imagine-dragons_its-time.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/phillip-phillips_gone-gone-gone.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/seafret_atlantis.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/mac-demarco_my-kind-of-woman.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/mitski_washing-machine-heart.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/weyes-blood_andromeda.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/niall-horan_put-a-little-love-on-me.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/harry-styles_to-be-so-lonely.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/chris-cornell_like-a-stone.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/lilly-wood-the-prick_prayer-in-c.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/eddie-vedder_tonight-you-belong-to-me.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/one-direction_perfect.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/onerepublic_i-lived.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/cage-the-elephant_telescope.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/the-kooks_taking-pictures-of-you.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/green-day_ordinary-world.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/chet-faker_talk-is-cheap.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/rex-orange-county_sunflower.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/aaron-lewis_travelin-soldier.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/jack-stauber_buttercup.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/the-lumineers_gloria.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/cage-the-elephant_trouble.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/taylor-swift_better-than-revenge.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/ruelle_i-get-to-love-you.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/fun-_some-nights.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/alt-j_breezeblocks.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/brandi-carlile_the-joke.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/u2_summer-of-love.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/men-i-trust_show-me-how.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/cavetown_juliet.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/dayglow_can-i-call-you-tonight.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/pamungkas_to-the-bone.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/birdy_skinny-love.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/seiler-und-speer_ham-kummst.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/mac-demarco_chamber-of-reflection.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/onerepublic_counting-stars.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/plain-white-ts_rhythm-of-love.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/die-toten-hosen_tage-wie-diese.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/the-new-basement-tapes_kansas-city.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/arctic-monkeys_i-wanna-be-yours.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/big-thief_shark-smile.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/sunrise-avenue_hollywood-hills.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/imagine-dragons_whatever-it-takes.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/rend-collective_build-your-kingdom-here.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/alt-j_left-hand-free.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/manchester-orchestra_the-silence.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/hozier_angel-of-small-death-and-the-codeine-scene.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/louis-tomlinson_two-of-us.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/sir-chloe_animal.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/harry-styles_fine-line.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/harry-styles_sunflower-vol-6.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/the-neighbourhood_sweater-weather.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/tom-odell_heal.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/cage-the-elephant_cigarette-daydreams.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/lady-gaga_joanne.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/arctic-monkeys_whyd-you-only-call-me-when-youre-high.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/2010/4/taylor-swift_state-of-grace.txt
