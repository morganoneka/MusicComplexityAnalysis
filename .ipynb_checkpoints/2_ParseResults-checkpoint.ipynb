# %% [markdown]
# # Web scraping
#
# In this notebook, we will parse the raw data we saved in the last notebook. The output will be a dictionary (saved as a `.json` file) that contains info about song structure and chord progression.

# %%
import requests
from bs4 import BeautifulSoup
import re
from itertools import chain
import json
from collections import Counter
import os
import random
import music_functions as mf

# %%
input_dir = '/Volumes/SECONDDRIVE/prog/ug/raw_data/'
output_dir = '/Volumes/SECONDDRIVE/prog/ug/chord_dicts/'

# %%
decade_dirs = [f.path for f in os.scandir(input_dir) if f.is_dir() and f.path.split("/")[-1].isnumeric()]

# %%
# iterate over each decade
for decade_dir in decade_dirs:
    
    decade = decade_dir.split("/")[-1]
    if not os.path.exists(output_dir + decade):
        os.mkdir(output_dir + decade)
    
    # iterate over each genre
    genre_dirs = [f.path for f in os.scandir(decade_dir) if f.is_dir()]
    
    for genre_dir in genre_dirs:
        
        genre = genre_dir.split("/")[-1]
        if not os.path.exists(output_dir + decade + "/" + genre):
            os.mkdir(output_dir + decade + "/" + genre)
        
        filelist = [input_dir+ decade + "/" + genre + "/" + x for x in os.listdir(input_dir+ decade + "/" + genre + "/")]
        
        for fname in filelist:    

            # check to see if we've already parsed this data before
            outname = output_dir + decade + "/" + genre + "/" + fname.split(".")[0].split("/")[-1] + ".json"
            if os.path.isfile(outname):
#                 print("file has already been analyzed")
                continue

            print(fname)

            with open(fname, 'r') as file:
                data = file.read().replace('\n', '')

            soup = BeautifulSoup(data, "html.parser")

            results = soup.find_all("div", class_="_3naMH")    

            # Identify the key signature and capo
            key_search = [x.get_text().split()[1] for x in results if "Key" in x.get_text()]

            key_signature = 0
            if (len(key_search) > 0):
                key_signature = key_search[0]

            # Identify the guitar tuning (which can impact effect of the capo)
            tuning_search = [ ' '.join(x.get_text().split()[1:]) for x in results if "Tuning" in x.get_text()]    
            tuning_offset = 0

            # there shouldn't be a scenario where tuning search has more than one element
            # either there's 1 (the tuning) or 0 (no tuning specified - assume standard)
            if (len(tuning_search) == 1):
                tuning = tuning_search[0]

                # ignore standard tuning EADGBE and drop D DADGBE because the offset will still be zero
                if tuning == 'E A D G B E' or tuning == 'D A D G B E':
                    tuning_offset = 0
                # half-step down tuning
                elif tuning == 'Eb Ab Db Gb Bb Eb' or tuning == 'D# G# C# F# A# D#':
                    tuning_offset = 1
                elif tuning == 'C G C F A D' or tuning == 'D G C F A D': # d or drop c tuning
                    tuning_offset = 2
                else: # other tunings not currently supported... could return later
                    print("This was a weird tuning")
                    print(tuning)
                    continue

            capo_search = [x.get_text().split()[1] for x in results if "Capo" in x.get_text()]
            capo = 0
            if (len(capo_search) > 0):
                # regex is used to remove any letters (so changing "3rd" to just "3")
                capo = int(re.sub("[^0-9]", "", capo_search[0]))


            # a capo transposes up, and the tuning generally transposes down
            transpose_offset = capo - tuning_offset

            # identify the locations of different sections
            try:
                song_spans = soup.find_all("pre", class_="_3F2CP _3hukP")[0].find_all("span")
                
                    # identify where the section headers are
                section_header_match = [bool(re.match("<span class=\"_3rlxz\">\[.*\]</span>", str(song_spans[x]))) for x in range(len(song_spans))]
                section_header_idx = [i for i, val in enumerate(section_header_match) if val]
                section_headers = [song_spans[x].get_text() for x in section_header_idx]
                section_header_idx.append(len(song_spans))

                # get chord progression for each section
                chord_progression = {}

                for init_index in range(len(section_header_idx)-1):
                    section = song_spans[section_header_idx[init_index]: section_header_idx[init_index+1]]
                    section_chords = [x.get_text().strip().split() for x in section if str(x).startswith('<span class="_3rlxz">') and '_3PpPJ OrSDI' in str(x)]

                    # removing the equivalencies that some people insert re: capo 
                    section_chords = [x for x in section_chords if '=' not in x]

                    # un-nest list
                    section_chords = [mf.clean_chord(x) for x in list(chain.from_iterable(section_chords))]

                    # remove any special characters (this might remove some info but that's ok)
                    special_characters = ['*', '~']
                    section_chords = [''.join([e for e in x if e not in special_characters]) for x in section_chords]

                    # remove anything else that doesn't match
                    section_chords = [x for x in section_chords if re.match(r"^[ABCDEFG][#b]*[ABCDEFG#bm]*$", x)]

                    chord_progression[init_index] = { 'type' : section_headers[init_index], 'chords' : section_chords}

                # if the chord_progression dictionary is empty, then skip this step
                # this might happen because the song doesn't have labels for different parts of the song (intro, verse, chorus, etc.)
                if not chord_progression:
                    print("Chord progression dictionary is empty")
                    continue

                #TODO so in all cases it's not technically the most occurring (ex: fluorescent adolescent)
                # this could be a good enough approximation tho i guess lol
                if key_signature == 0:
                    key_signature = mf.infer_tonic(mf.get_all_chords(chord_progression))
                else:
                    key_signature = mf.apply_capo(key_signature, transpose_offset)

                # convert to numerics for easier comparison
                for section in chord_progression:
                    chords = chord_progression[section]['chords']
                    chord_progression[section]['chords_numeric'] = [mf.get_relation(key_signature, x) for x in chords]


                with open(outname, 'w') as outfile:
                    json.dump(chord_progression, outfile)
            except:
                continue
# Out:
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/eagles_hotel-california.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/pink-floyd_wish-you-were-here.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/creedence-clearwater-revival_have-you-ever-seen-the-rain.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/elton-john_your-song.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/john-lennon_imagine.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/the-beatles_let-it-be.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/queen_bohemian-rhapsody.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/cat-stevens_father-and-son.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/fleetwood-mac_landslide.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/eagles_take-it-easy.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/lynyrd-skynyrd_sweet-home-alabama.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/neil-young_heart-of-gold.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/bee-gees_how-deep-is-your-love.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/queen_love-of-my-life.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/elton-john_rocket-man.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/eric-clapton_wonderful-tonight.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/fleetwood-mac_dreams.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/america_a-horse-with-no-name.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/billy-joel_piano-man.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/led-zeppelin_stairway-to-heaven.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/george-harrison_my-sweet-lord.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/neil-diamond_sweet-caroline.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/queen_dont-stop-me-now.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/dire-straits_sultans-of-swing.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/elton-john_goodbye-yellow-brick-road.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/kansas_dust-in-the-wind.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/cat-stevens_wild-world.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/the-beatles_across-the-universe.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/acdc_highway-to-hell.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/pink-floyd_comfortably-numb.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/the-rolling-stones_wild-horses.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/queen_crazy-little-thing-called-love.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/lynyrd-skynyrd_simple-man.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/eric-clapton_nobody-knows-you-when-youre-down-and-out.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/david-bowie_starman.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/eagles_peaceful-easy-feeling.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/queen_somebody-to-love.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/david-bowie_heroes.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/janis-joplin_me-and-bobby-mcgee.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/simon-garfunkel_bridge-over-troubled-water.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/billy-joel_vienna.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/james-taylor_fire-and-rain.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/bob-seger-the-silver-bullet-band_night-moves.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/pink-floyd_time.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/fleetwood-mac_the-chain.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/eagles_desperado.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/eagles_lyin-eyes.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/elton-john_tiny-dancer.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/eagles_tequila-sunrise.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/fleetwood-mac_go-your-own-way.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/lynyrd-skynyrd_free-bird.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/neil-young_old-man.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/the-beatles_the-long-and-winding-road.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/the-kinks_lola.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/david-bowie_life-on-mars.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/queen_we-are-the-champions.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/pink-floyd_mother.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/aerosmith_dream-on.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/stealers-wheel_stuck-in-the-middle-with-you.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/jimmy-buffett_margaritaville.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/deep-purple_smoke-on-the-water.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/billy-joel_just-the-way-you-are.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/billy-joel_shes-always-a-woman.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/bob-seger-the-silver-bullet-band_turn-the-page.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/cat-stevens_morning-has-broken.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/the-rolling-stones_angie.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/the-police_roxanne.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/john-lennon_jealous-guy.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/grateful-dead_ripple.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/the-beatles_dont-let-me-down.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/van-morrison_into-the-mystic.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/eagles_new-kid-in-town.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/the-who_behind-blue-eyes.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/rod-stewart_i-dont-want-to-talk-about-it.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/queen_killer-queen.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/creedence-clearwater-revival_wholl-stop-the-rain.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/pink-floyd_breathe.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/elton-john_crocodile-rock.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/tom-petty-and-the-heartbreakers_american-girl.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/simon-garfunkel_scarborough-fair.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/the-cure_boys-dont-cry.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/lou-reed_perfect-day.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/billy-joel_new-york-state-of-mind.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/david-bowie_ziggy-stardust.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/supertramp_give-a-little-bit.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/kiss_i-was-made-for-lovin-you.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/the-marshall-tucker-band_cant-you-see.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/lou-reed_walk-on-the-wild-side.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/pink-floyd_brain-damage.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/neil-young_hey-hey-my-my-into-the-black.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/david-bowie_moonage-daydream.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/deep-purple_soldier-of-fortune.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/electric-light-orchestra_mr-blue-sky.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/pink-floyd_another-brick-in-the-wall-part-2.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/the-rolling-stones_dead-flowers.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/the-doors_riders-on-the-storm.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/rod-stewart_maggie-may.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/the-allman-brothers-band_melissa.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/eric-carmen_all-by-myself.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/carly-simon_youre-so-vain.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/bette-midler_the-rose.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/grateful-dead_friend-of-the-devil.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/rey-valera_kahit-maputi-na-ang-buhok-ko.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/elvis-presley_always-on-my-mind.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/the-beatles_get-back.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/boston_more-than-a-feeling.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/america_sister-golden-hair.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/elton-john_candle-in-the-wind.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/eagles_best-of-my-love.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/creedence-clearwater-revival_lookin-out-my-back-door.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/bob-dylan_tangled-up-in-blue.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/redbone_come-and-get-your-love.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/paul-mccartney_maybe-im-amazed.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/smokie_living-next-door-to-alice.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/queen_we-will-rock-you.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/lynyrd-skynyrd_tuesdays-gone.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/harry-chapin_cats-in-the-cradle.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/eric-clapton_cocaine.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/peter-frampton_baby-i-love-your-way.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/kansas_carry-on-wayward-son.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/black-sabbath_paranoid.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/neil-young_my-my-hey-hey-out-of-the-blue.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/eagles_take-it-to-the-limit.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/bob-dylan_simple-twist-of-fate.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/pink-floyd_hey-you.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/creedence-clearwater-revival_i-heard-it-through-the-grapevine.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/neil-young_after-the-gold-rush.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/neil-young_the-needle-and-the-damage-done.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/toto_hold-the-line.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/carole-king_youve-got-a-friend.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/john-lennon_working-class-hero.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/uriah-heep_lady-in-black.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/joan-jett_i-love-rock-n-roll.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/elvis-presley_burning-love.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/america_ventura-highway.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/david-bowie_the-man-who-sold-the-world.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/david-bowie_rock-n-roll-suicide.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/van-morrison_moondance.txt
# file has already been analyzed
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/10cc_im-not-in-love.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/blondie_heart-of-glass.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/david-bowie_changes.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/the-velvet-underground_sweet-jane.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/james-taylor_sweet-baby-james.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/carole-king_will-you-love-me-tomorrow.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/simon-garfunkel_cecilia.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/bob-dylan_hurricane.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/rod-stewart_sailing.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/the-doobie-brothers_listen-to-the-music.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/the-beatles_two-of-us.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/faces_ooh-la-la.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/nazareth_love-hurts.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/grateful-dead_brokedown-palace.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/queen_good-old-fashioned-lover-boy.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/elton-john_bennie-and-the-jets.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/bread_if.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/steve-miller-band_the-joker.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/bread_everything-i-own.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/joe-cocker_you-are-so-beautiful.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/tim-buckley_song-to-the-siren.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/simon-garfunkel_the-only-living-boy-in-new-york.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/queen_fat-bottomed-girls.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/zz-top_la-grange.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/fleetwood-mac_songbird.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/elton-john_daniel.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/chicago_if-you-leave-me-now.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/bruce-springsteen_born-to-run.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/pink-floyd_echoes.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/fleetwood-mac_rhiannon.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/the-police_message-in-a-bottle.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/hall-oates_rich-girl.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/bob-dylan_one-more-cup-of-coffee.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/the-rolling-stones_sweet-virginia.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/peter-gabriel_solsbury-hill.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/carole-king_its-too-late.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/eric-clapton_i-shot-the-sheriff.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/queen_39.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/talking-heads_psycho-killer.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/alice-cooper_poison.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/jackson-browne_these-days.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/santana_black-magic-woman.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/crosby-stills-nash-young_teach-your-children.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/jim-croce_i-got-a-name.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/led-zeppelin_going-to-california.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/acdc_tnt.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/paul-simon_me-and-julio-down-by-the-schoolyard.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/the-kinks_strangers.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/rainbow_temple-of-the-king.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/bonnie-raitt_angel-from-montgomery.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/bee-gees_more-than-a-woman.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/crosby-stills-nash-young_helpless.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/the-rolling-stones_gimme-shelter.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/peter-frampton_show-me-the-way.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/crosby-stills-nash-young_our-house.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/bob-dylan_shelter-from-the-storm.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/carole-king_so-far-away.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/linda-ronstadt_blue-bayou.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/elvis-presley_thats-alright-mama.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/rupert-holmes_escape-the-pina-colada-song.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/4/led-zeppelin_kashmir.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/14/bee-gees_how-deep-is-your-love.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/14/kenny-rogers_the-gambler.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1970/14/abba_the-winner-takes-it-all.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/chris-isaak_wicked-game.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/guns-n-roses_sweet-child-o-mine.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/pixies_where-is-my-mind.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/tracy-chapman_fast-car.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/toto_africa.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/a-ha_take-on-me.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/the-police_every-breath-you-take.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/guns-n-roses_patience.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/elton-john_can-you-feel-the-love-tonight.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/tom-petty_free-fallin.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/prince_purple-rain.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/u2_with-or-without-you.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/bryan-adams_summer-of-69.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/bryan-adams_heaven.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/journey_dont-stop-believin.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/crowded-house_dont-dream-its-over.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/the-smiths_there-is-a-light-that-never-goes-out.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/elton-john_im-still-standing.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/poison_every-rose-has-its-thorn.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/sting_englishman-in-new-york.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/bruce-springsteen_the-river.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/bruce-springsteen_dancing-in-the-dark.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/tom-petty_i-wont-back-down.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/bruce-springsteen_im-on-fire.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/acdc_back-in-black.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/survivor_eye-of-the-tiger.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/u2_i-still-havent-found-what-im-looking-for.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/eurythmics_sweet-dreams-are-made-of-this.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/guns-n-roses_dont-cry.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/phil-collins_against-all-odds.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/the-cure_just-like-heaven.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/queen_i-want-to-break-free.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/iggy-pop_the-passenger.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/bon-jovi_wanted-dead-or-alive.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/bon-jovi_livin-on-a-prayer.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/the-proclaimers_im-gonna-be-500-miles.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/cyndi-lauper_time-after-time.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/dire-straits_romeo-and-juliet.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/bonnie-tyler_total-eclipse-of-the-heart.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/carpenters_close-to-you.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/scorpions_still-loving-you.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/acdc_you-shook-me-all-night-long.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/violent-femmes_blister-in-the-sun.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/richard-marx_right-here-waiting.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/men-at-work_down-under.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/pixies_hey.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/simple-minds_dont-you-forget-about-me.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/tracy-chapman_baby-can-i-hold-you.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/the-smiths_please-please-please-let-me-get-what-i-want.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/queen_under-pressure.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/phil-collins_in-the-air-tonight.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/bob-seger-the-silver-bullet-band_against-the-wind.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/4/traveling-wilburys_end-of-the-line.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/mike-oldfield_moonlight-shadow.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/jean-jacques-goldman_je-te-donne.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/talking-heads_and-she-was.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/rick-astley_never-gonna-give-you-up.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/leonard-cohen_im-your-man.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/roxy-music_more-than-this.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/culture-club_karma-chameleon.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/kate-bush_babooshka.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/prince_little-red-corvette.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/jean-jacques-goldman_comme-toi.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/michael-jackson_bad.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/michael-jackson_pyt-pretty-young-thing.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/amy-grant_el-shaddai.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/cyndi-lauper_time-after-time.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/celine-dion_how-does-a-moment-last-forever.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/patrick-swayze_shes-like-the-wind.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/barry-manilow_somewhere-down-the-road.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/roxette_the-look.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/john-farnham_youre-the-voice.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/wolfgang-petry_wahnsinn.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/paul-young_every-time-you-go-away.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/the-bangles_eternal-flame.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/jeanette_el-muchacho-de-los-ojos-tristes.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/chaka-khan_through-the-fire.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/modern-talking_youre-my-heart-youre-my-soul.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/francis-cabrel_sarbacane.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/whitney-houston_how-will-i-know.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/rod-stewart_forever-young.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/paul-mccartney_mull-of-kintyre.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/marc-lavoine_elle-a-les-yeux-revolver.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/laura-branigan_self-control.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/abba_gimme-gimme-gimme.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/roxy-music_avalon.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/nik-kershaw_wouldnt-it-be-good.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/the-b-52s_love-shack.txt
# Chord progression dictionary is empty
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/paul-mccartney_say-say-say.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/air-supply_here-i-am.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/alain-souchon_la-ballade-de-jim.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/kari-tapio_olen-suomalainen.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/hombres-g_devuelveme-a-mi-chica.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/the-alan-parsons-project_old-and-wise.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1980/14/george-michael_careless-whisper.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1990/4/jeff-buckley_hallelujah.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1990/4/oasis_wonderwall.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1990/4/radiohead_creep.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1990/4/oasis_dont-look-back-in-anger.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1990/4/the-cranberries_zombie.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1990/4/4-non-blondes_whats-up.txt
# /Volumes/SECONDDRIVE/prog/ug/raw_data/1990/4/goo-goo-dolls_iris.txt
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-d73999476002> in <module>
#      66             if (len(capo_search) > 0):
#      67                 # regex is used to remove any letters (so changing "3rd" to just "3")
# ---> 68                 capo = int(re.sub("[^0-9]", "", capo_search[0]))
#      69
#      70
#
# ValueError: invalid literal for int() with base 10: ''
