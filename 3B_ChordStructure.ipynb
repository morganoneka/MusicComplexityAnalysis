# %% [markdown]
# # Looking at chord progressions
#
# In this notebook I'm going to look at chord progressions (overall, not for specific sections or anything)

# %%
import re
from itertools import chain
import json
import os
from itertools import chain
import pandas as pd
import music_functions as mf

# %%
input_dir = "/Volumes/SECONDDRIVE/prog/ug/chord_dicts/2000/4/"
structure_dict = mf.get_chord_structure_dict([input_dir + x for x in os.listdir(input_dir)])

# %%
[key for key in structure_dict]
# Out:
# ['intro',
#  'verse',
#  'chorus',
#  'interlude',
#  'bridge',
#  'outro',
#  'intro riff',
#  'solo',
#  'pre-chorus',
#  'instrumental',
#  'chords',
#  'break',
#  'instrumental fill',
#  'verse riff',
#  'pre/post-chorus riff',
#  'chorus riff',
#  'her:',
#  'him:',
#  'both:',
#  'trumpet section',
#  'guitar solo',
#  'post-chorus',
#  'fill',
#  'coda',
#  'hook',
#  'bass interlude',
#  'outro solo',
#  'tabs during instrumental',
#  'instrumental tabs',
#  'refrain',
#  'chorus/outro',
#  'chorus a',
#  'chorus b',
#  'whistle solo',
#  'tab for st chorus',
#  'riff',
#  'kid rock',
#  'sheryl crow',
#  'both',
#  'middle eight',
#  'chorus & outro',
#  'final-chorus',
#  'fingerpicking intro',
#  'rock intro',
#  'i. jesus of suburbia',
#  'ii. city of the damned',
#  "iii. i don't care",
#  'iv. dearly beloved',
#  'v. tales of another broken home',
#  'little outro riff',
#  'pre-hook',
#  'middle',
#  'alternative intro',
#  'alternative chorus',
#  'lyrics',
# ...

# %%
structure_dict['intro']
# Out:
# {'I': {'V': 36,
#   'I': 18,
#   'ii': 10,
#   'iii': 10,
#   'Not In Key Signature': 18,
#   'IV': 23,
#   'vi': 17},
#  'V': {'IV': 14,
#   'vi': 13,
#   'ii': 4,
#   'Not In Key Signature': 6,
#   'V': 3,
#   'I': 25},
#  'IV': {'I': 35,
#   'Not In Key Signature': 1,
#   'IV': 4,
#   'iii': 1,
#   'vi': 11,
#   'V': 9,
#   'ii': 2},
#  'ii': {'Not In Key Signature': 3,
#   'V': 13,
#   'vi': 6,
#   'I': 6,
#   'ii': 3,
#   'IV': 1,
#   'iii': 1},
#  'iii': {'I': 9, 'ii': 2, 'IV': 1, 'iii': 1, 'V': 6, 'vi': 2},
#  'Not In Key Signature': {'Not In Key Signature': 161,
#   'IV': 8,
#   'I': 5,
#   'vi': 4,
#   'II': 2,
#   'iii': 3,
#   'i': 3,
#   'VI': 2,
#   'ii': 6,
#   'V': 1},
#  'vi': {'IV': 27,
#   'I': 7,
#   'V': 12,
#   'ii': 5,
#   'Not In Key Signature': 4,
#   'vi': 3,
#   'iii': 10},
#  'II': {'Not In Key Signature': 1, 'i': 4, 'VI': 1, 'VII': 2},
#  'i': {'iv': 7,
#   'Not In Key Signature': 3,
#   'II': 2,
#   'VII': 2,
#   'VI': 5,
#   'v': 1,
#   'i': 1},
# ...

# %%
structure_df = pd.DataFrame.from_dict(mf.clean_structure_dict(structure_dict['intro'], 10)).fillna(0)

# %%
structure_df
# Out:
#                        I     V  IV  ii  iii  Not In Key Signature  vi
# V                     36   3.0   9  13  6.0                     1  12
# I                     18  25.0  35   6  9.0                     5   7
# ii                    10   4.0   2   3  2.0                     6   5
# iii                   10   0.0   1   1  1.0                     3  10
# Not In Key Signature  18   6.0   1   3  0.0                   161   4
# IV                    23  14.0   4   1  1.0                     8  27
# vi                    17  13.0  11   6  2.0                     4   3
